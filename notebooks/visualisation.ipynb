# %%
from agage_archive.widgets import dashboard

# %%
dashboard("agage", mode="markers")
# Out:
# Dropdown(description='Species:', options=('c2f6', 'c3f8', 'c4f8', 'ccl2ccl2', 'ccl4', 'cf4', 'cfc-11', 'cfc-11…
# Dropdown(description='File type:', options=('high-frequency', 'monthly-baseline', 'individual-instruments'), v…
# SelectMultiple(description='Site, instrument:', options=('cgo, agage', 'cmn, agage', 'gsn, agage', 'jfj, agage…
# Dropdown(description='Variable:', options=('mf', 'mf_repeatability', 'mf_variability', 'mf_count', 'inlet_heig…
# Button(description='Plot', style=ButtonStyle())
# Output()
# Output()
